# %%
import logging
import logging.config
logging.config.fileConfig('logging_config.ini')
from soso.job import Job
Job1 = Job(name="job1",start="2025-02-02T11:12:06",end="2025-02-02T12:12:06",priority=2,latitude=120,longitude=100,delivery="2025-03-02T12:12:06")
Job2 = Job(name="job2",start="2025-02-02T11:12:06",end="2025-02-02T12:12:06",priority=2,latitude=140,longitude=120,delivery="2025-03-02T12:12:06")

# %%
from soso.utils import parse_ground_stations,parse_satellites, parse_two_line_elements, print_api_result

# %%
from pathlib import Path
import os
from colorama import Fore
from skyfield.api import load
ts = load.timescale()
eph = load('de421.bsp')
# Define directories containing the satellites and orders data
project_dir = Path(os.path.dirname(''))
data_dir = project_dir / 'data'
order_data_dir = data_dir / 'orders'
satellite_data_dir = data_dir / 'satellites'
outage_request_data_dir = data_dir / 'outages'
ground_station_data_dir = data_dir / 'ground_stations'
two_line_elements = parse_two_line_elements(satellite_data_dir)

# Parse satellites and orders data
satellites = parse_satellites(satellite_data_dir, ts)
ground_stations = parse_ground_stations(ground_station_data_dir)

# %%
# Generate intervals for each satellite
from soso.interval_tree import generate_satellite_intervals
from soso.utils import SchedulerServer 
from soso.interface import ScheduleOutput, ScheduleParameters
jobs = (Job1,Job2)
outage_requests= ()
satellite_passes = generate_satellite_intervals(
    satellites,
    jobs,
    outage_requests,
    ground_stations,
    (),
    ts,
    eph
)
satellite_intervals = satellite_passes.satellite_intervals
ground_station_passes = satellite_passes.ground_station_passes
# Out:
# 2025-03-14 20:19:04,735 - soso.interval_tree.satellite_interval_trees - [INFO] - Making the interval trees took 0.3439290523529053 seconds

# %%
import time
import requests
import json
try:
    server = SchedulerServer()
    server.start()
    params = ScheduleParameters(
        input_hash=None,
        two_line_elements=two_line_elements,
        jobs=jobs,
        ground_stations=ground_stations,
        outage_requests=outage_requests,
        ground_station_outage_requests=[]
    )
    
    alg_t0 = time.time()
    
    # Send a test request
    response = requests.post(
        f'http://localhost:{os.environ.get("PORT", 8000)}/schedule',
        headers={"Content-Type": "application/json"},
        json=json.loads(params.model_dump_json())
    )
    
    if response.status_code == 200:
        alg_t1 = time.time()
    
        time.sleep(1)
    
        solution = ScheduleOutput.model_validate(response.json())
    
        print_api_result(solution, style=Fore.GREEN)
    
    
        jobs_scheduled = sum([
            len(planned_orders)
                for planned_orders in solution.planned_orders.values()
        ])
        print(
            f'{jobs_scheduled} out of {len(jobs)} jobs scheduled in '
                f'{alg_t1 - alg_t0} seconds'
        )
    else:
        print(f'Response status: {response.status_code}')
        print(response.content)
    
except Exception as e:
    print('Error in API call')
    print(e)
    
finally:
    if server:
        server.stop()
# Out:
# stdout from the server will be printed in cyan
# stderr from the server will be printed in red
# 2025-03-14 20:19:06,680 - uvicorn.error - [INFO] - Started server process [20790]
# 2025-03-14 20:19:06,680 - uvicorn.error - [INFO] - Waiting for application startup.
# 2025-03-14 20:19:06,680 - uvicorn.error - [INFO] - Application startup complete.
# 2025-03-14 20:19:06,681 - uvicorn.error - [INFO] - Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# 2025-03-14 20:19:09,887 - soso.api - [INFO] - Received scheduling request from 127.0.0.1:56320
# 2025-03-14 20:19:10,176 - soso.interval_tree.satellite_interval_trees - [INFO] - Making the interval trees took 0.2798178195953369 seconds
# 2025-03-14 20:19:10,177 - soso.genetic.genetic_scheduler - [INFO] - Starting genetic algorithm
# 2025-03-14 20:19:10,181 - soso.network_flow.network_flow_scheduler - [INFO] - Total network flow runtime (without plotting): 0.003635883331298828
# 2025-03-14 20:19:10,207 - soso.bin_packing.ground_station_bin_packing - [INFO] - Bin packing took 0.02578592300415039 seconds
# 2025-03-14 20:19:10,207 - soso.genetic.genetic_scheduler - [INFO] - Generation: 0, best fitness: 13.0
# 2025-03-14 20:19:10,208 - soso.network_flow.network_flow_scheduler - [INFO] - Total network flow runtime (without plotting): 0.0007519721984863281
# 2025-03-14 20:19:10,245 - soso.bin_packing.ground_station_bin_packing - [INFO] - Bin packing took 0.036699771881103516 seconds
# 2025-03-14 20:19:10,248 - soso.network_flow.network_flow_scheduler - [INFO] - Total network flow runtime (without plotting): 0.0017600059509277344
# 2025-03-14 20:19:10,286 - soso.bin_packing.ground_station_bin_packing - [INFO] - Bin packing took 0.038179874420166016 seconds
# 2025-03-14 20:19:10,288 - soso.network_flow.network_flow_scheduler - [INFO] - Total network flow runtime (without plotting): 0.0012030601501464844
# 2025-03-14 20:19:10,327 - soso.bin_packing.ground_station_bin_packing - [INFO] - Bin packing took 0.0383601188659668 seconds
# 2025-03-14 20:19:10,331 - soso.network_flow.network_flow_scheduler - [INFO] - Total network flow runtime (without plotting): 0.003631114959716797
# 2025-03-14 20:19:10,374 - soso.bin_packing.ground_station_bin_packing - [INFO] - Bin packing took 0.0429990291595459 seconds
# 2025-03-14 20:19:10,379 - soso.network_flow.network_flow_scheduler - [INFO] - Total network flow runtime (without plotting): 0.0025043487548828125
# 2025-03-14 20:19:10,418 - soso.bin_packing.ground_station_bin_packing - [INFO] - Bin packing took 0.03878903388977051 seconds
# 2025-03-14 20:19:10,422 - soso.network_flow.network_flow_scheduler - [INFO] - Total network flow runtime (without plotting): 0.0033359527587890625
# 2025-03-14 20:19:10,460 - soso.bin_packing.ground_station_bin_packing - [INFO] - Bin packing took 0.038156986236572266 seconds
# 2025-03-14 20:19:10,464 - soso.network_flow.network_flow_scheduler - [INFO] - Total network flow runtime (without plotting): 0.0031270980834960938
# 2025-03-14 20:19:10,495 - soso.bin_packing.ground_station_bin_packing - [INFO] - Bin packing took 0.0312042236328125 seconds
# 2025-03-14 20:19:10,498 - soso.network_flow.network_flow_scheduler - [INFO] - Total network flow runtime (without plotting): 0.0025298595428466797
# 2025-03-14 20:19:10,531 - soso.bin_packing.ground_station_bin_packing - [INFO] - Bin packing took 0.032423973083496094 seconds
# 2025-03-14 20:19:10,532 - soso.network_flow.network_flow_scheduler - [INFO] - Total network flow runtime (without plotting): 0.0007069110870361328
# 2025-03-14 20:19:10,552 - soso.bin_packing.ground_station_bin_packing - [INFO] - Bin packing took 0.020081043243408203 seconds
# 2025-03-14 20:19:10,552 - soso.genetic.genetic_scheduler - [INFO] - Generation: 1, best fitness: 13.0
# 2025-03-14 20:19:10,554 - soso.network_flow.network_flow_scheduler - [INFO] - Total network flow runtime (without plotting): 0.0013718605041503906
# 2025-03-14 20:19:10,574 - soso.bin_packing.ground_station_bin_packing - [INFO] - Bin packing took 0.019817829132080078 seconds
# 2025-03-14 20:19:10,576 - soso.network_flow.network_flow_scheduler - [INFO] - Total network flow runtime (without plotting): 0.0015797615051269531
# 2025-03-14 20:19:10,597 - soso.bin_packing.ground_station_bin_packing - [INFO] - Bin packing took 0.02082991600036621 seconds
# 2025-03-14 20:19:10,599 - soso.network_flow.network_flow_scheduler - [INFO] - Total network flow runtime (without plotting): 0.0017240047454833984
# 2025-03-14 20:19:10,622 - soso.bin_packing.ground_station_bin_packing - [INFO] - Bin packing took 0.022814035415649414 seconds
# 2025-03-14 20:19:10,624 - soso.network_flow.network_flow_scheduler - [INFO] - Total network flow runtime (without plotting): 0.0016410350799560547
# 2025-03-14 20:19:10,648 - soso.bin_packing.ground_station_bin_packing - [INFO] - Bin packing took 0.023808956146240234 seconds
# 2025-03-14 20:19:10,650 - soso.network_flow.network_flow_scheduler - [INFO] - Total network flow runtime (without plotting): 0.0019459724426269531
# 2025-03-14 20:19:10,673 - soso.bin_packing.ground_station_bin_packing - [INFO] - Bin packing took 0.022419214248657227 seconds
# 2025-03-14 20:19:10,673 - soso.genetic.genetic_scheduler - [INFO] - Generation: 2, best fitness: 13.0
# 2025-03-14 20:19:10,675 - soso.network_flow.network_flow_scheduler - [INFO] - Total network flow runtime (without plotting): 0.0014758110046386719
# 2025-03-14 20:19:10,698 - soso.bin_packing.ground_station_bin_packing - [INFO] - Bin packing took 0.022661209106445312 seconds
# 2025-03-14 20:19:10,699 - soso.network_flow.network_flow_scheduler - [INFO] - Total network flow runtime (without plotting): 0.001207113265991211
# 2025-03-14 20:19:10,723 - soso.bin_packing.ground_station_bin_packing - [INFO] - Bin packing took 0.02382183074951172 seconds
# 2025-03-14 20:19:10,725 - soso.network_flow.network_flow_scheduler - [INFO] - Total network flow runtime (without plotting): 0.0017228126525878906
# 2025-03-14 20:19:10,745 - soso.bin_packing.ground_station_bin_packing - [INFO] - Bin packing took 0.019713878631591797 seconds
# 2025-03-14 20:19:10,748 - soso.network_flow.network_flow_scheduler - [INFO] - Total network flow runtime (without plotting): 0.002183198928833008
# 2025-03-14 20:19:10,771 - soso.bin_packing.ground_station_bin_packing - [INFO] - Bin packing took 0.022895097732543945 seconds
# 2025-03-14 20:19:10,773 - soso.network_flow.network_flow_scheduler - [INFO] - Total network flow runtime (without plotting): 0.0022499561309814453
# 2025-03-14 20:19:10,793 - soso.bin_packing.ground_station_bin_packing - [INFO] - Bin packing took 0.019387006759643555 seconds
# 2025-03-14 20:19:10,793 - soso.genetic.genetic_scheduler - [INFO] - Generation: 3, best fitness: 13.0
# 2025-03-14 20:19:10,796 - soso.network_flow.network_flow_scheduler - [INFO] - Total network flow runtime (without plotting): 0.0027692317962646484
# 2025-03-14 20:19:10,817 - soso.bin_packing.ground_station_bin_packing - [INFO] - Bin packing took 0.02025771141052246 seconds
# 2025-03-14 20:19:10,819 - soso.network_flow.network_flow_scheduler - [INFO] - Total network flow runtime (without plotting): 0.0018210411071777344
# 2025-03-14 20:19:10,839 - soso.bin_packing.ground_station_bin_packing - [INFO] - Bin packing took 0.02053213119506836 seconds
# 2025-03-14 20:19:10,842 - soso.network_flow.network_flow_scheduler - [INFO] - Total network flow runtime (without plotting): 0.0018482208251953125
# 2025-03-14 20:19:10,862 - soso.bin_packing.ground_station_bin_packing - [INFO] - Bin packing took 0.019916057586669922 seconds
# 2025-03-14 20:19:10,864 - soso.network_flow.network_flow_scheduler - [INFO] - Total network flow runtime (without plotting): 0.0018649101257324219
# 2025-03-14 20:19:10,888 - soso.bin_packing.ground_station_bin_packing - [INFO] - Bin packing took 0.024135112762451172 seconds
# 2025-03-14 20:19:10,890 - soso.network_flow.network_flow_scheduler - [INFO] - Total network flow runtime (without plotting): 0.0015239715576171875
# 2025-03-14 20:19:10,911 - soso.bin_packing.ground_station_bin_packing - [INFO] - Bin packing took 0.02036118507385254 seconds
# 2025-03-14 20:19:10,911 - soso.genetic.genetic_scheduler - [INFO] - Generation: 4, best fitness: 13.0
# 2025-03-14 20:19:10,913 - soso.network_flow.network_flow_scheduler - [INFO] - Total network flow runtime (without plotting): 0.0024199485778808594
# 2025-03-14 20:19:10,936 - soso.bin_packing.ground_station_bin_packing - [INFO] - Bin packing took 0.022153854370117188 seconds
# 2025-03-14 20:19:10,939 - soso.network_flow.network_flow_scheduler - [INFO] - Total network flow runtime (without plotting): 0.002485990524291992
# 2025-03-14 20:19:10,962 - soso.bin_packing.ground_station_bin_packing - [INFO] - Bin packing took 0.0232999324798584 seconds
# 2025-03-14 20:19:10,964 - soso.network_flow.network_flow_scheduler - [INFO] - Total network flow runtime (without plotting): 0.0016582012176513672
# 2025-03-14 20:19:10,989 - soso.bin_packing.ground_station_bin_packing - [INFO] - Bin packing took 0.024852991104125977 seconds
# 2025-03-14 20:19:10,990 - soso.network_flow.network_flow_scheduler - [INFO] - Total network flow runtime (without plotting): 0.0007150173187255859
# 2025-03-14 20:19:11,011 - soso.bin_packing.ground_station_bin_packing - [INFO] - Bin packing took 0.021134138107299805 seconds
# 2025-03-14 20:19:11,014 - soso.network_flow.network_flow_scheduler - [INFO] - Total network flow runtime (without plotting): 0.0019979476928710938
# 2025-03-14 20:19:11,035 - soso.bin_packing.ground_station_bin_packing - [INFO] - Bin packing took 0.021351099014282227 seconds
# 2025-03-14 20:19:11,036 - soso.genetic.genetic_scheduler - [INFO] - Genetic algorithm took 0.8582220077514648 seconds
# 2025-03-14 20:19:11,038 - soso.network_flow.network_flow_scheduler - [INFO] - Total network flow runtime (without plotting): 0.0023381710052490234
# 2025-03-14 20:19:11,061 - soso.bin_packing.ground_station_bin_packing - [INFO] - Bin packing took 0.02249002456665039 seconds
# 2025-03-14 20:19:11,062 - uvicorn.access - [INFO] - 127.0.0.1:56320 - "POST /schedule HTTP/1.1" 200
# Satellite: SOSO-1
# Satellite: SOSO-2
# Satellite: SOSO-3
# Satellite: SOSO-4
# Satellite: SOSO-5
# Impossible orders: []
# Impossible orders from ground stations: []
# Impossible orders from outages: []
# Rejected orders: [job1 P2, job2 P2]
# 0 out of 2 jobs scheduled in 1.2042710781097412 seconds
# 2025-03-14 20:19:12,632 - uvicorn.error - [INFO] - Shutting down
# 2025-03-14 20:19:12,733 - uvicorn.error - [INFO] - Waiting for application shutdown.
# 2025-03-14 20:19:12,734 - uvicorn.error - [INFO] - Application shutdown complete.
# 2025-03-14 20:19:12,734 - uvicorn.error - [INFO] - Finished server process [20790]
